# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("iris.csv")

print("First 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("\nDataset Information:")
print(df.info())

print("\nStatistical Summary:")
print(df.describe())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# Statistical Summary:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 3

# %%
plt.figure(figsize=(6,5))

sns.countplot(x='species', data=df)

plt.title('Count of Iris Species')
plt.xlabel('Species')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(6,5))

plt.hist(df['sepal_length'], bins=10)

plt.title('Sepal Length Distribution')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.scatterplot(
    x='sepal_length',
    y='petal_length',
    hue='species',
    data=df
)

plt.title('Sepal Length vs Petal Length')

plt.show()

# %%
sns.pairplot(df, hue='species')

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df.drop(columns=['species']).corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')

plt.show()

# %%
print("\n========== FINAL INSIGHTS ==========\n")

print("1. The dataset contains three iris flower species:")
print("   Setosa, Versicolor, and Virginica with equal distribution.\n")

print("2. Setosa species is clearly distinguishable from the other species")
print("   because it has smaller petal dimensions.\n")

print("3. Virginica flowers generally have the largest petal dimensions,")
print("   while Versicolor lies between Setosa and Virginica.\n")

print("4. The scatter plot shows a strong positive relationship")
print("   between sepal length and petal length.\n")

print("5. Petal-related features provide better species separation")
print("   compared to sepal-related features.\n")

print("6. The correlation heatmap shows that petal length and")
print("   petal width are highly positively correlated.\n")

print("7. Sepal width has weaker correlation with other features.\n")

print("8. Data visualization helps in understanding patterns,")
print("   relationships, and classification in the Iris dataset.\n")
